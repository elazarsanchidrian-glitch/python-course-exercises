# %%
temp_today = int(input ("what is the temp today?: "))
if temp_today > 35:
  print("its hot today")
if temp_today <35:
  print("colder today")
# Out:
# what is the temp today?: 36
# its hot today

# %%
username = input("enter username: ")
password = input("enter password: ")
if username == "laz123" and password == "raz123":
  print("success")
else:
  print("failure")
# Out:
# enter username: laz123
# enter password: raz123
# success

# %%
high_score = int(input ("enter highscore: "))
if high_score > 500:
  print("new high score")
if high_score < 500:
  print("new low score")
# Out:
# enter highscore: 499
# new low score

# %%
new_hotel_guest_name = input("guest name is: ")
new_hotel_guest_age = int(input("guest age is: "))
if new_hotel_guest_name == "Elazar" and new_hotel_guest_age >=18 :
  print("welcome aboard")
else:
  print("leave now")
# Out:
# guest name is: Elazar
# guest age is: 19
# welcome aboard

# %%
allowed_rollercoaster_height = int(input("what is your height in cm: "))

if allowed_rollercoaster_height >= 140 and allowed_rollercoaster_height <= 180:
    print("allowed")
else:
    print("not allowed")
# Out:
# what is your height in cm: 180
# allowed

# %%
pool_entry_user = int(input("Entry to the pool allowed only if you are below 12 or over 80, enter your age: "))

if pool_entry_user >= 80 or pool_entry_user <= 12:
    print("you are allowed to enter")
else:
    print("not allowed")
# Out:
# Entry to the pool allowed only if you are below 12 or over 80, enter your age: 13
# not allowed

# %%
math_grade = int(input("enter grade: "))
science_grade = int(input("enter second grade: "))
if math_grade >= 60 and science_grade >= 60:
  print("great success!")
else:
  print("you failed get lost!")
# Out:
# enter grade: 60
# enter second grade: 60
# great success!

# %%
pick_a_number = int(input("number between 10 and 20: "))
if 10 <= pick_a_number <= 20:
    print("valid number")
else:
  print("invalid")
# Out:
# number between 10 and 20: 10
# valid number

# %%
your_age = int(input("tell me your age: "))
if your_age >= 13 and your_age <= 19:
   print("you are a teenager: ")
if your_age < 12:
    print("you are too young: ")
if your_age > 19:
  print("you are an adult: ")
# Out:
# tell me your age11
# you are too young

# %%
user_sum_purchase = int(input("how much did you buy it for?: "))
cupon = input("you have a cupon? yes or no?: ")
if user_sum_purchase >= 100 or cupon == "yes":
  print("you get a discount!")
else:
  print("sorry no discount")
# Out:
# how much did you buy it for?: 101
# you have a cupon? yes or no?: no
# you get a discount!

# %%
user_favorite_color = input("your fav color is?: ")
if user_favorite_color == "blue" or user_favorite_color == "red" or user_favorite_color == "green":
    print("nice choice")
else:
    print("boring")
# Out:
# your fav color is?: green
# nice choice

# %%
user_age_verify = int(input("what is your age: "))
vip_ticket = input("you have VIP ticket? yes/no: ")

is_adult = user_age_verify >= 18
has_vip = vip_ticket == "yes"
is_valid_age = not user_age_verify > 120

if is_adult and (has_vip or user_age_verify >= 21) and is_valid_age:
    print("You may enter the VIP event!")
else:
    print("Access denied")
