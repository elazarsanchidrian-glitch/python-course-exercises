# %% [markdown]
# 1 -
# Ask the user if they like vanilla ice cream, and ask them to enter the response Yes or No.
# If the user did not enter Yes then print "Sorry you do not like vanilla ice cream.

# %%
user = input("do you like vanilla ice cream?")
if user == "yes":
    print("you do like vanilla ice cream!")
else:
        print("sorry you do not like vanilla ice cream")
# Out:
# do you like vanilla ice cream?no
# sorry you do not like vanilla ice cream

# %% [markdown]
# 2 -
# Age Checker
# Ask the user for their age.
# Print one of three messages depending on whether the user is:
# under 4,
# between 4–12,
# or older than 12,
# using if/elif/else..

# %%
age_check_user = int(input("what is your age?"))
if age_check_user < 4:
    print("you are under 4")

elif age_check_user >= 4 and age_check_user <= 12:
    print("you are between 4 and 12")

else:
    print("you are older than 12")
# Out:
# what is your age?13
# you are older than 12

# %% [markdown]
# 3 -
# Weather Advice
# Ask the user what the weather is like (sunny, rainy, snowy), using if/elif/else.
# Print a different suggestion for each case.

# %%
weather = input("what the weather is like in your area, is it cold warm or mild")
if weather == "cold":
  print("cold weather")

elif weather == "warm":
  print("warm weather")

elif weather == "mild":
  print("mild weather")
else:
  print("no input detected")
# Out:
# what the weather is like in your area, is it cold warm or mildjdkajkdv
# no input detected

# %% [markdown]
# 4 -
# Ask the user for the amount of their purchase.
# If the amount is above 100, print "You <amount entered> qualify for a discount!".
# Use an fstring to print the message

# %%
user_purchase_amount = int(input("is your amount above 100?"))
if user_purchase_amount >= 100:
    print(f"your {user_purchase_amount} qualify for a discount!")
if user_purchase_amount < 100:
    print(f"your {user_purchase_amount} does not qualify for a discount!")
# Out:
# is your amount above 100?99
# your 99 does not qualify for a discount!

# %% [markdown]
# 5 -
# Challenge: Login System
# Ask for username and password.
# If both match predefined values, print 'Login successful'.
# Otherwise, print an error message.

# %%
username = input("enter username: ")
password = input ("enter password: ")
if username == "john123":
  print("login username success")
else:
  print("login username failure")
if password == "condor123":
  print("password success")
else:
  print("password failure")
# Out:
# enter username: ghghg
# enter password: ghghg
# login username failure
# password failure

# %% [markdown]
# 6 - Ask the user for the day of the week (string).
# If the day is "Saturday" or "Sunday", print "Yay! It's the weekend!".
# Otherwise print "Still not the weekend, hang in there!"

# %%
user_day = input("what is the day today: ")
if user_day == "sunday" or user_day == "saturday":
  print("yay its weekend")
else:
  print("hang on there")
# Out:
# what is the day today: monday
# hang on there

# %% [markdown]
# 7 -
# Write a program that receives three numbers, calculates their average, and prints:
# •	"The average <the average number> is greater than 5" if the average is greater than 5
# •	"The average <the average number> is exactly 5" if the average equals 5
# •	"The average <the average number> is less than 5" if the average is less than 5
# Use an fstring to print the message

# %%
first_number = int(input("enter first number: "))
second_number = int(input("enter second number: "))
third_number = int(input("enter third and final number: "))
average =int( (first_number + second_number + third_number) / 3 )
print(f"Average: {average}")
if average > 5:
  print("avg greater than 5")
if average < 5:
  print("avg smaller than 5")
if average == 5:
  print("avg equals to 5")
# Out:
# enter first number: 3
# enter second number: 5
# enter third and final number: 7
# Average: 5
# avg equals to 5

# %% [markdown]
# 9 -
# Use an if statement to check whether the number entered is even, using the % operator.
# If the number is even, print a message saying that it is even and print the number.
#
# Add an else statement to handle the case where the number is odd.
# In this case, print a message saying that it is odd and print the number.

# %%
number = int(input("Enter a number: "))

if number % 2 == 0:
    print("The number is even:", number)
else:
    print("The number is odd:", number)

# %% [markdown]
# **10** -
# Write a Python program that asks the user to enter a number.
# Then:
# If the number is divisible by 3, print "Fizz".
# If the number is divisible by 5, print "Buzz".
# If the number is divisible by both 3 and 5, print "FizzBuzz".
# If the number is not divisible by either 3 or 5, print the number itself.

# %%
number = int(input("Enter a number: "))

if number % 3 == 0 and number % 5 == 0:
    print("FizzBuzz")
elif number % 3 == 0:
    print("Fizz")
elif number % 5 == 0:
    print("Buzz")
else:
    print(number)

# %% [markdown]
# 11 -
# Ask the user for:
# - a first number
# - a second number
# - an operation (+, -, *, /)
#
# Using if/elif/else,
# calculate and print the result with an fstring as:
# <the first number> <the operation> <the second number> = <the calculation result>
# example: 5 * 2 = 10

# %%
first_number = int(input("Enter first number: "))
second_number = int(input("Enter second number: "))
operation = input("Enter operation (+, -, *, /): ")

if operation == "+":
    result = first_number + second_number

elif operation == "-":
    result = first_number - second_number

elif operation == "*":
    result = first_number * second_number

elif operation == "/":
    result = first_number / second_number

else:
    result = "Invalid operation"

print(f"{first_number} {operation} {second_number} = {result}")

# %% [markdown]
# 12 -
# Ask the user to enter a number.
#
# If the number is positive, print:
# "The number is positive"
#
# If the number is negative, print:
# "The number is negative"
#
# Otherwise print:
# "The number is zero"

# %% [markdown]
# 14 -
# Ask the user to enter a number.
#
# Check if the number is divisible by BOTH 2 and 3.
#
# If it is, print:
# "The number <number> is divisible by both 2 and 3"
#
# Otherwise print:
# "The number <number> is not divisible by both 2 and 3"
# Use fstring to print

# %%
user_number = int(input("Enter a number: "))

if user_number % 2 == 0 and user_number % 3 == 0:
    print(f"{user_number} is divisible by both 2 and 3")
else:
    print(f"{user_number} is not divisible by both 2 and 3")

# %% [markdown]
# **15** -
# Ask the user for the purchase amount.
#
# If the amount is greater than 200,
# calculate a 20% discount and print the new price.
#
# Otherwise print the original price.

# %%
user_purchase_amount = int(input("Enter purchase amount: "))

if user_purchase_amount > 200:
    new_price = user_purchase_amount * 0.8
    print(new_price)
else:
    print(user_purchase_amount)

# %% [markdown]
# 16 -
# Ask the user for a username.
#
# If the username is empty,
# print:
# "You must enter a username"
#
# Otherwise print:
# "Welcome!"

# %%
user_name = input("enter username here: ")
if user_name == "":
  print("please enter a valid username: ")
else:
  print("correct you may procceed")
# Out:
# enter username here: haha
# correct you may procceed
