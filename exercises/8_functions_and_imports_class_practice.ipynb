# %%
def print_hello():
    print('hello')
print_hello()
print_hello()
# Out:
# hello
# hello

# %%
def input_icecream_flavor():
    input("your fav flavor?: ")
input_icecream_flavor()
input_icecream_flavor()
input_icecream_flavor()
# Out:
# your fav flavor?: vanilla
# your fav flavor?: choco
# your fav flavor?: berry

# %%
def make_juice(fruit):
    print("squeezing fruit: " , fruit)

make_juice("Orange")
make_juice("Lemon")
# Out:
# squeezing fruit:  Orange
# squeezing fruit:  Lemon

# %%
fruits = ["banana", "lemon", "orange", "strawberry"]
for fruit in fruits:
    def make_juice(fruits):
        print("sqeezing fruit: " , fruits)
make_juice(fruits)
# Out:
# sqeezing fruit:  ['banana', 'lemon', 'orange', 'strawberry']

# %%
fruits = ["banana", "lemon", "orange", "strawberry"]
for fruit in fruits:
     make_juice(fruit)
# Out:
# sqeezing fruit:  banana
# sqeezing fruit:  lemon
# sqeezing fruit:  orange
# sqeezing fruit:  strawberry

# %%
def welcome(menu):
    print("welcome to resturant 'lovers' ")
    answer = input("been here?")
    if answer == "no":
        print(menu)

welcome("Pizza restaurant menu:   pizza margarita, pizza with pineapple")
# Out:
# welcome to resturant 'lovers'
# been here?yes

# %%
import random

def greet(name):
    print("hi",  name ,  "welcome")


name = random.choice("Elazar", "Menachem")
greet(name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_446/2327684744.py in <cell line: 0>()
#       5
#       6
# ----> 7 name = random.choice[("Elazar", "Menachem")]
#       8 greet(name)
#
# TypeError: 'method' object is not subscriptable

# %%
def three_times(num):
    print(num * 3)

three_times(3)
three_times(2)
three_times(4)
# Out:
# 9
# 6
# 12

# %%
def add_numbers(num1,num2):
    result = num1 + num2
    print("the sum is: " , result)

add_numbers(4,7)
# Out:
# the sum is:  11

# %%
def add_numbers(num1,num2):
    print(num1 + num2)



add_numbers(1,2)
# Out:
# 3

# %%
def substract_numbers(num1,num2):
    result=num1-num2
    print("the sum is: " , result)
substract_numbers(6,3)
# Out:
# the sum is:  3

# %%
def food_item(food_name , food_price):
    print("food: " , food_name)
    print(f"final price: {food_price * 1.18} ")
food_item("Milk", 1.18)
# Out:
# food:  Milk
# final price: 1.3923999999999999

# %%
name = "tal"
age = 27
person_details = (name, age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_446/3028305650.py in <cell line: 0>()
#       2 age = 27
#       3 person_details = (name, age)
# ----> 4 print(person_details)
#
# TypeError: 'tuple' object is not callable

# %%
def substract_numbers(num1, num2):
    result = num1 - num2
    return result

difference = substract_numbers(7,4)
print(difference)
# Out:
# 3

# %%
def substract_numbers(num1,num2):
    result = num1 - num2
    return result
# Out:
# 6 3

# %%
def get_age():
    input("how old are you?: ")


get_age()
get_age()
# Out:
# how old are you?: 11
# how old are you?: 12

# %%
constants: (variable uppercase letters)
MAX_SIZE=100
DAYS_IN_WEEK=7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_446/2014415103.py in <cell line: 0>()
#       2 cat_owner = "John"
#       3 cat_name_list = ["pepe", "dapi", "bubo"]
# ----> 4 print(cat_owner , cat_name_list)
#
# TypeError: 'NoneType' object is not callable

# %%
import string
print(string.ascii_letters)
print(string.ascii_uppercase)
print(string.ascii_lowercase)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_446/2911116029.py in <cell line: 0>()
#       1 import string
# ----> 2 print(string.ascii_letters)
#       3 print(string.ascii_uppercase)
#       4 print(string.ascii_lowercase)
#
# TypeError: 'NoneType' object is not callable

# %%
import random
import string

#print(random.choice(string.ascii_letters))
print(random.choice(["True", "False"]))
print(random.choice([True, False]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_446/2672748356.py in <cell line: 0>()
#       3
#       4 #print(random.choice(string.ascii_letters))
# ----> 5 print(random.choice(["True", "False"]))
#       6 print(random.choice([True, False]))
#
# TypeError: 'NoneType' object is not callable
