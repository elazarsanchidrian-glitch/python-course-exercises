# %%
len("pizza")
# Out:
# 5

# %%
word = "cat"

print(word.startswith("c"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3211/2830523525.py in <cell line: 0>()
# ----> 1 startswith("pizza")
#
# NameError: name 'startswith' is not defined
