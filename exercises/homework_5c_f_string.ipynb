# %%
game_name = "minecraft"
hours_played = 168
print(f"a fun game is {game_name} with {hours_played} hours played")
# Out:
# a fun game is minecraft with 168 hours played

# %%
student_name = "yon"
grade = 67
print("Name:" , student_name , "\nGrade:" , grade)
print("Name:" , student_name + " " + "\nGrade" , grade)
print(f"Name: {student_name} \nGrade: {grade}")
# Out:
# Name: yon
# Grade: 67
# Name: yon
# Grade 67
# Name: yon
# Grade: 67

# %%
movie = "avatar"
ticket_price = "40 shekels"
print(f"the movie {movie} costs {ticket_price}")
# Out:
# the movie avatar costs 40 shekels

# %%
price = 10
tax_price = 5
print(f"the price is {price} and the total price is {tax_price + price}")
# Out:
# the price is 10 and the total price is 15

# %%
num1 = 10
num2 = 20
print(f"sum of 10 plus 20 is {num1 + num2}")
# Out:
# sum of 10 plus 20 is 30

# %%
awful_music = "awful modern pop music"
superior_metal_music_fans = "metalheads"
overwhelming_musical_knowledge = "otherworldly sounds and smells"
the_end = "he dies"
print(f"Ben loves! {awful_music}\n,He enjoys bragging about it with {superior_metal_music_fans}\n,He gets overwhelmed by {overwhelming_musical_knowledge}\n,and {the_end}\n")
# Out:
# Ben loves! awful modern pop music
# ,He enjoys bragging about it with metalheads
# ,He gets overwhelmed by otherworldly sounds and smells
# ,and he dies

# %%
name = "Dana"
age = "20"
print("Name: " + name + "\n Age: " + age)
# Out:
# Name: Dana
#  Age: 20

# %%
country = "republic of dave"
population = 20
print(f"the population of {country} is {population}")
print(country , population)
print(country +  str (population) )
print(country + " " + str(population))
# Out:
# the population of republic of dave is 20
# republic of dave 20
# republic of dave20
# republic of dave 20

# %%
first_name = "Alex"
last_name = "Mercer"
age = 21
city = "New York"
favorite_hobby = "playing video games"

print(f"Hi my name is {first_name} {last_name}, Aged {21}, and I live in {city}.\n I love {favorite_hobby}!")
# Out:
# Hi my name is Alex Mercer, Aged 21, and I live in New York.
#  I love playing video games!
