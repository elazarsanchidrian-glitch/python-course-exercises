# %%
is_sunny_out = True
has_sunglasses = False

is_sunny_out = "True"
has_sunglasses = "False"

# %%
cat1 = 4
cat2 = 11
print("is cat1 bigger than cat2?")
print(cat1 > cat2)
print("no")
print("is cat1 same value as cat2?")
print(cat1 == cat2)
print("no")
print("is cat1 smaller than cat2?")
print(cat1 < cat2)
print("yes")
# Out:
# is cat1 bigger than cat2?
# False
# no
# is cat1 same value as cat2?
# False
# no
# is cat1 smaller than cat2?
# True
# yes

# %%
cat1 = 4
cat2 = 11
if (cat1 > cat2):
    print("yes")
else:
    print("no")
#
# Out:
# no

# %%
if (10 > 5):
    print("pizza cookies")
if (5 < 10):
    print("no pizza cookies!")
# Out:
# pizza cookies
# no pizza cookies!

# %%
print(10 > 5)
print(3 == 3)
print("hello" != "Hello")

print(10<5)
print(3>3)
print("hello" == "goodbye")
# Out:
# True
# True
# True
# False
# False
# False

# %%
age = 17
if age >= 16:
  print("cats")
cats = 18
if cats != 17:
  print("no cats!")

is_raining = True
has_umbrella = True
if is_raining and has_umbrella:
  print("that's more like it")
# Out:
# cats
# no cats!
# that's more like it

# %%
has_license = input("do you have a license yes or no\n")
print(has_license)

if(has_license == "yes"):
    print("has license")
# Out:
# do you have a license yes or no
# no
# no

# %%
is_raining = True

if is_raining:
    print("don't go outside")
# Out:
# don't go outside

# %%
name = "john"
print(name != "john")
# Out:
# False

# %%
c = 6
d = 17
print(c * d <= 50 )
print(c * d >= 50 )
print(c * d == 50 )
print(c * d != 50 )
print(c * d / 2 == 50 )
# Out:
# False
# True
# False
# True
# False

# %%
a = 8
b = 3
print(a + b == 11)
print(a * 2 < b + 10)

c = 6
d = 17
print(c * d <= 50 )
# Out:
# True
# False
# False

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

average = (num1 + num2 + num3) / 3

if average > 5:
    print("The average is greater than 5")

elif average == 5:
    print("The average is exactly 5")

else:
    print("The average is less than 5")

# %%
num = 200
print(num > 100)
# Out:
# True

# %%
num1 = 10
num2 = 20

print(num1 > num2)
print(num1 < num2)
print(num1 >= num2)
print(num1 <= num2)
print(num1 == num2)
print(num1 != num2)
# Out:
# False
# True
# False
# True
# False
# True

# %%
name1 = input("enter a name: ")
name2 = input("enter another name")
if name1 == name2:
    print("the names are the same")
else:
    print("the names are not the same")
# Out:
# enter a name: john
# enter another namelaz
# the names are not the same

# %%
has_ticket = True
has_no_ticket = False

input("do you have a ticket yes or no\n")
if(has_ticket == "yes"):
    print("has ticket")

if(has_no_ticket == "no"):
    print("has no ticket")
# Out:
# do you have a ticket yes or no
# no

# %%
answer = input("Do you have a ticket? yes or no or maybe\n")

if answer == "yes":
    print("has ticket")

if answer == "no":
    print("has no ticket")

if answer == "maybe":
    print("he doesn't know")
# Out:
# Do you have a ticket? yes or no or maybe
# maybe
# he doesn't know

# %%
answer = input("enter a number\n:")

if answer / 3:
    print("yes")
else:
    print("no")
# Out:
# enter a number
# :10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8878/2560210564.py in <cell line: 0>()
#       1 answer = input("enter a number\n:")
#       2
# ----> 3 if answer / (int3):
#       4     print("yes")
#       5 else:
#
# NameError: name 'int3' is not defined

# %%
number = int(input("Enter a number: "))

print(number % 3 == 0)
# Out:
# Enter a number: 7
# False
