# %%
candles = 6
kids = 3
print(candles / kids )
print(candles // kids)
print(candles % kids)
laptops = 7
students = 5
print(laptops // students)
print(laptops / students)
print(laptops % students)

print(5 % 3)
print(6 % 2)
# Out:
# 2.0
# 2
# 0
# 1
# 1.4
# 2
# 2
# 0

# %%
number = 6
(number % 2 == 0)
# Out:
# True

# %%
number = 5
(number % 2 == 0)
# Out:
# False

# %%
number = 7
(number % 5 == 0)
# Out:
# False

# %%
number = 10
(number % 5 == 0)
# Out:
# True

# %%
num1 = 10
num2 = 11
num3 = 12
num4 = 13
if (num1/3) : then
# Out:
#   File "/tmp/ipykernel_24200/3356999022.py", line 5
#     if (num1/3) :
#                   ^
# SyntaxError: incomplete input

# %%
number = int(input("Enter a number: "))

if number % 3 == 0 and number % 5 == 0:
    print("FizzBuzz")
elif number % 3 == 0:
    print("Fizz")
elif number % 5 == 0:
    print("Buzz")
else:
    print(number)
