# %% [markdown]
# 1)
# Write a for loop using the range() function that prints your name 10 times

# %% [markdown]
# 2)
# Write a for loop using the range() function that prints all the numbers
# from 1 to 20, including 20

# %% [markdown]
# 3)
# Write a for loop using the range() function that prints:
# 2, 4, 6, 8, 10
# (Hint - use step 2)

# %% [markdown]
# 4)
# Write a for loop using the range() function that prints all
# the numbers from 1 to 100 in increments of 5
# (Hint - use step)

# %% [markdown]
# 5)
# Write a for loop using the range() function that runs from 0 to 10,
# including the number 10'
#
# For even numbers it will print "even number"
#
# for odd numbers it will print "odd number"
#
# Hint: use modulo

# %% [markdown]
# 6)
# Write a program that accepts the user's first name as input
#
# Saves the name in a variable
#
# And prints it 20 times

# %% [markdown]
# 7)
# Write a program that accepts an integer from the user as input.
#
# The program will print all the numbers from 1 to the number entered
# by the user, including the user input number

# %% [markdown]
# 8)
# Counting Backwards
#
# Write a for loop using the range() function that prints
# the number 10 to 1 (backwards)
#
# (Hint: use a negative step)

# %% [markdown]
# 9)
# Counting Backwards
#
# Write a for loop using the range() function that prints:
#
# 10, 8, 6, 4, 2
#
# (Hint: use a negative step)

# %% [markdown]
# 10)
# Counting Backwards
#
# Write a for loop using the range() function that prints from 20 down to 10,
# including 10

# %% [markdown]
# 11)
# What numbers will this loop print?
#
# for i in range(0, 12, 3):
#     print(i)
#
# Now change the code so it also prints the number 12

# %% [markdown]
# 12)
# This code is supposed to count down from 7 to 1, but it doesn’t print anything.
#
# Fix it so it works:
#
# for i in range(1, 7, -1):
#     print(i)

# %% [markdown]
# 13)
# Write a for loop that prints every third number between 30 and 15 (counting down).
#
# Including 30 but not including 15
#
# Expected output:
#
# 30, 27, 24, 21, 18
#
# Then make it include 15
#
# Expected output:
#
# 30, 27, 24, 21, 18, 15

# %% [markdown]
# 14)
# Ask the user to enter two numbers: a start and a stop.
#
# If start < stop → print all numbers from start to stop counting up.
#
# If start > stop → print all numbers from start to stop counting down.

# %% [markdown]
# 15)
# Write a for loop that prints the numbers 2 to 10, but stops if the number is
# greater than 5.

# %% [markdown]
# 16)
# What is the outcome of each of these code loops below?
#
# stop = 10
#
# for i in range(stop):
#     print(i)
#
# for i in range(0, stop, 1):
#     print(i)

# %% [markdown]
# 17)
# Write a for loop that prints the numbers 2 to 10,
# but skips the numbers 5 and 7 using the continue keyword.

# %% [markdown]
# 18)
# Write a for loop that prints all the numbers from 0 to 100
# in increments of 5
#
# Then edit the code and make it not print any of these numbers
# that are divisible by 10

# %% [markdown]
# 19)
# Write a for loop that prints numbers from 1 to 10
# but skips the number 3 using continue.
#
# Now edit this loop to stop completely when it reaches 7 using break.

# %% [markdown]
# 20)
# Write a for loop that prints all multiples of 3 between 3 and 18

# %% [markdown]
# 21)
# Print numbers from 50 to 40, skipping every 2

# %% [markdown]
# 22)
# Print the numbers from 20 down to 0, counting by 2s.
