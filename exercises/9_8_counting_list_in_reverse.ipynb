# %%
days = ["sunday", "monday", "tuesday", "wednsday", "thursday", "friday", "saturday"]
for day in reversed(days):
    print(day)
# Out:
# saturday
# friday
# thursday
# wednsday
# tuesday
# monday
# sunday
