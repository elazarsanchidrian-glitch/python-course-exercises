# %%
first_name = "Shlomit"
last_name = "Becker"
age = 36
print(first_name + " " + last_name + " \n"+ str(age))
print(first_name , last_name + " \n" +str(age))
# Out:
# Shlomit Becker
# 36
# Shlomit Becker
# 36
