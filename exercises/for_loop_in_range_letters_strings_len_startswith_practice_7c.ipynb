# %%
for letter in "Hello":
  print(letter)
# Out:
# H
# e
# l
# l
# o

# %%
fruits = ["apple" , "pear" , "orange"]
for fruit in fruits:
  print(fruit)
len(fruits)
# Out:
# apple
# pear
# orange
# 3

# %%
name = "Elazar"
for letter in name:
  print(letter)
# Out:
# E
# l
# a
# z
# a
# r

# %%
name = "Elazar"
print(len(name))


if name.startswith("E"):
  print(name)
# Out:
# 6
# Elazar

# %%
if 'l' in "Elazar":
    True

# %%
if "l" not in "Elazar":
    False

# %%
name = "Elazar"

print(name.upper())
print(name.lower())

letter = "e"
print(letter in name)
print(letter in name.lower())
# Out:
# ELAZAR
# elazar
# False
# True
