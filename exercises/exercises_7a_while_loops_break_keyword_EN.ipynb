# %% [markdown]
# 1)
# Write a while loop that prints your name 20 times

# %% [markdown]
# 2)
# Now update the previous program to ask the user to enter their name and use that name in the loop

# %% [markdown]
# 3)
# Write a while loop to print numbers from 1 to 10.
# Skip the numbers 3 and 6 when printing, just print the rest of the numbers.

# %% [markdown]
# 4)
# Write a program that accepts an integer from the user as input.
# The program then uses a while loop to print all the numbers from 1 to the number entered by the user,
# including the number that the user entered

# %% [markdown]
# 5.
#
# Write a Python program that keeps asking the user to enter whole numbers in a loop, and adds them together to end in one sum. The maximum allowed value for the sum is 100.
#
#
# **The program should:**
#
# Keep track of the sum with a variable called: total_sum, with a starting value of 0.
#
# Then, inside a loop:
#
# Ask the user to enter a whole number
#
# Before adding the number to total_sum:
#
# check if adding the number would make total_sum become greater than 100
#
# If adding the number would make the total go over 100:
#
# do NOT add the number to the total_sum
# stop the loop
#
# If adding the number to the total_sum would not make it go over 100 then add it to the total_sum
#
# When the code exits the loop then:
# Print the final total_sum

# %% [markdown]
# 6) "7 boom" -
#
# Write a program that receives an integer from the user as input.
# The program will use a while loop
# and will print all the numbers from 1 to the number the user entered,
# but when it reaches a number divisible by 7 it will print "boom".
# For example, for the number 16 we will print: 1 2 3 4 5 6 Boom 8 9 10 11 12 13 Boom 15 16
# (hint - use the % operator)

# %% [markdown]
# 7)
# Write a program that receives as input whole numbers repeatedly from the user,
# until the user asks to stop by writing "stop"
# Use a while loop.
# hint: use the break keyword

# %% [markdown]
# 8)
# Write a program that uses a while loop:  `while True:`
# to ask the user to enter a password until they type the correct one (e.g., 'python123').
# When the password is correct, print 'Access granted' and exit the loop.

# %% [markdown]
# 9)
# Improve the last program by allowing the user to enter the word 'stop' to end the program.

# %% [markdown]
# 10)
# Add numbers until the total is more than 50
# Ask the user to enter numbers.
# Keep a running total.
# Stop when the total is greater than 50.

# %% [markdown]
# 11)
# The school held a quiz for all 10th grade students.
#
# Write a program that will allow the teacher to input info for each student, one after the other.
#
# For each student the program will ask for the student's name, and the student's grade on the quiz, 2 values.
# Print the student's name and grade.
#
# The code should repeat this in a loop until there are no more students.
# The teacher can tell the program that there are no more students by entering the word "Done" instead of a student name in the inout() that asks for the student name.
# When Done is entered the loop should exit.
#
# The program will then count and print how many students got at least 60 on the test.
