# %%
name = input("What is your name?\n")
print(name)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7464/3100247178.py in <cell line: 0>()
# ----> 1 name = input("What is your name?\n")
#       2 print(name)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
# ...

# %%
favorite_color = input( "what is your favrorite color?\n")
print(favorite_color)

# %%
name = input("What is your name?\n")

age = input ("What is your age\n")

# %%
age = 27
age = input("what is your age?\n")
print(age)
another_guys_age = 30
another_guys_age = input("what is the age of another guy?\n")
print(another_guys_age)
final_result = 57
final_result = input("what is the final result?\n")
print(final_result)
# Out:
# what is your age?
# 27
# 27
# what is the age of another guy?
# 30
# 30
# what is the final result?
# 57
# 57

# %%
x = input("enter a number\n")
x = "4"
print(x)
# Out:
# enter a number
# 4
# 4

# %%
num1 = "10"
num2 = "20"
num3 = "30"
print(int(num1) + int(num2) + int(num3))
num4 = 7
text = "apples"
print(str(num4) + text)
# Out:
# 60
# 7apples

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print(num1 + num2)

print(int(input("First: ")) + int(input("Second: ")))
# Out:
# Enter first number: 1
# Enter second number: 2
# 3

# %%
print(int(input("First: ")) + int(input("Second: ")))
# Out:
# First: 1
# Second: 2
# 3

# %%
print(input("what is your name\n"))
print(input("what is your age\n"))
print(input("what is your favorite color\n"))
print(input("what is your favorite food\n"))
# Out:
# what is your name
# yav
# yav
# what is your age
# 25
# 25
# what is your favorite color
# blu
# blu
# what is your favorite food
# pizza
# pizza

# %%
name = input("Name? "); age = input("Age? "); color = input("Color? "); food = input("Food? ")
# Out:
# Name? elazar
# Age? 27
# Color? blue
# Food? pizza

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
sum = int(num1) + int(num2)
print(sum)
# Out:
# Enter first number: 1
# Enter second number: 2
# 3

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
sum = float(num1) * float(num2)
print(sum)
# Out:
# Enter first number: 5.5
# Enter second number: 6.6
# 36.3

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
sum = int(num1) // int(num2)
print(round(sum))
# Out:
# Enter first number: 30
# Enter second number: 5
# 6

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))
average = (int(num1) + int(num2) + int(num3)) / 3
print(average)
# Out:
# Enter first number: 4
# Enter second number: 6
# Enter third number: 8
# 6.0

# %%
input("what is your username?\n")
print("hello!")
# Out:
# what is your username?
# elazar123
# hello!

# %%
a = print(input("aa\n")*2)
# Out:
# aa
# aaa
# aaaaaa

# %%
a = print(input("aa\n"))
aa = print(input("aaa\n"))
aaa = print(input("aaaa\n"))
aaaa = print(input("aaaaa\n"))
# Out:
# aa
# a
# a
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7464/3520270035.py in <cell line: 0>()
#       1 a = print(input("aa\n"))
# ----> 2 aa = print(input("aaa\n"))
#       3 aaa = print(input("aaaa\n"))
#       4 aaaa = print(input("aaaaa\n"))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
left = input("Left side character: ")
top = input("Top side character: ")
right = input("Right side character: ")
bottom = input("Bottom side character: ")

print(top * 5)
print(left + "   " + right)
print(left + "   " + right)
print(left + "   " + right)
print(bottom * 5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1720/3506566156.py in <cell line: 0>()
# ----> 1 left = input("Left side character: ")
#       2 top = input("Top side character: ")
#       3 right = input("Right side character: ")
#       4 bottom = input("Bottom side character: ")
#       5
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
y = input("Enter a message")
print(y)
# Out:
# Enter a messagewat
# wat

# %%
x = input("Enter a number: ")
x = 9.6
y = input("Enter a number: ")
y = 3
print(x / y)
# Out:
# Enter a number: 9.6
# Enter a number: 3
# 3.1999999999999997

# %%
number = 10
number = 1- + 10
print (number)
# Out:
# -9

# %%
print(input("what is your age?\n"))
print("young!")
print(input("what is your name?\n"))
print("beautiful name!")
# Out:
# what is your age?
# 27
# 27
# young!
# what is your name?
# elazar
# elazar
# beautiful name!

# %%
x = input("Enter a number: ")
x = 2
y = input("Enter a number: ")
y = 5
print(x + y)
# Out:
# Enter a number: 2
# Enter a number: 5
# 7

# %%
a = input("Enter first number: ")
b = input("Enter second number: ")
print(a + b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1720/3006053134.py in <cell line: 0>()
# ----> 1 a = input("Enter first number: 6 ")
#       2 b = input("Enter second number: 5 ")
#       3
#       4 print(a + b)
#       5
#
# TypeError: 'int' object is not callable

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

average = (num1 + num2) / 2

print("Average:", average)



#i stopped in exercise 18, too many errors for no reason
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1720/3183771622.py in <cell line: 0>()
# ----> 1 num1 = float(input("Enter first number: "))
#       2 num2 = float(input("Enter second number: "))
#       3
#       4 average = (num1 + num2) / 2
#       5
#
# TypeError: 'int' object is not callable
