# %%
print((input("what is your user number?\n") + "\n") * 3)
# Out:
# what is your user number?
# 27
# 27
# 27
# 27

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print("Sum:", num1 + num2)
print("Difference:", num1 - num2)
print("Product:", num1 * num2)
# Out:
# Enter first number: 2
# Enter second number: 5
# Sum: 7
# Difference: -3
# Product: 10

# %%
print(str(5.6) + ' is a number')
print(5.6 + 'is a number')
# Out:
# 5.6 is a number
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_17308/4171977357.py in <cell line: 0>()
#       1 print(str(5.6) + ' is a number')
# ----> 2 print(5.6 + 'is a number')
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
print(int(5.6))
print(float(5.6))
print(str(5.6) + 'is a number')
print(type(str(5.6) + 'is a number'))
# Out:
# 5
# 5.6
# 5.6is a number
# <class 'str'>

# %%
print('age:' + (str(25)))
# Out:
# age:25

# %%
print(3 * 4)
# Out:
# 12

# %%
print(3 * 'Python')
print('Python' * 3)
# Out:
# PythonPythonPython
# PythonPythonPython

# %%
x = input('Enter a number: ')
y = input('Enter another number: ')
print(x + y
