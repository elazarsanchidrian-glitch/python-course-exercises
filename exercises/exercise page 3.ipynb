# %%
# @title
print(3+7)
print(2*5)
print(4-10)
print(type(4-10))
print(10-4)
print(type(10-4))
print(8.2-5.5)
print(type(8.2-5.5))
print(5.5-8.2)
print(type(5.5-8.2))
print(9/2)
print(9//2)
print(4.5/2)
print(10%4)
print(7%2)
print(2**4)
print(-3**3)
print((-2) ** 3)
print(round(10 / 3, 2))
print(round(5.6789, 1))
print(4 + 3.2)
# Out:
# 10
# 10
# -6
# <class 'int'>
# 6
# <class 'int'>
# 2.6999999999999993
# <class 'float'>
# -2.6999999999999993
# <class 'float'>
# 4.5
# 4
# 2.25
# 2
# 1
# 16
# -27
# -8
# 3.33
# 5.7
# 7.2

# %%
print(round((90+87+78)/3))
number = 6
number % 2 == 0
print(number)
print(number % 2 == 0)
print(type(number))
print((3 + 4) * 2)
print(3+4 *2)
result = ( 5+2 ) / 3
print(result)
print(type(result))
math_equation = 10 + 3 * 2 - 1
print(math_equation)
print(type(math_equation))
print(10.5 * 2)
a_value = "100"
add_another = 20
print (int(a_value) + add_another)
# Out:
# 85
# 6
# True
# <class 'int'>
# 14
# 11
# 2.3333333333333335
# <class 'float'>
# 15
# <class 'int'>
# 21.0
# 120

# %%
print(3 + 2)
print((4 + 2) * 6-1)
print(type((4 + 2) * 6-1)) #int
print(float((4 + 2) * 6-1)) #35.0
# Out:
# 5
# 35
# <class 'int'>
# 35.0

# %%
print((13-4) / (12*12))
print(type(4*3))
print(type(4.0*3))
print(int(1/2))
# Out:
# 0.0625
# <class 'int'>
# <class 'float'>
# 0

# %%
meters = 100
feet = 3.2808 * meters
meters = 200
feet = 3.2808 * meters
print(feet)
print(round(feet))
print(int(feet))
print(type(int(feet)))
#
# Out:
# 656.1600000000001
# 656
# 656
# <class 'int'>

# %%
print('Hello' + 'World') #true
print('3' + 3) #false
print(3 + 3.5) #true
print('Hello' * 2) #true
print(2 * 'Hi') #true
print('Hi' / 2) #false
# Out:
# HelloWorld
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2950/3414472957.py in <cell line: 0>()
#       1 print('Hello' + 'World') #true
# ----> 2 print('3' + 3) #false
#       3 print(3 + 3.5) #true
#       4 print('Hello' * 2) #true
#       5 print(2 * 'Hi') #true
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(5 + int('10'))
example_1 = "cat"
example_2 = 67
example_3 = 6.7
print(example_2 + example_3)
print(example_1 + str(example_2) +str(example_3))
# Out:
# 15
# 73.7
# cat676.7

# %%
num1 = 8
num2 = 3
print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
# Out:
# 11
# 5
# 24
# 2.6666666666666665

# %%
x = 5
y = 2
print(x / y)
print(x // y)
print(x % y)
# Out:
# 2.5
# 2
# 1

# %%
print(type(5 + 2))
print((5+2))
print(type(5 / 2))
print(5 / 2)
print(type(5 // 2))
print(type(5.0 + 2))
# Out:
# <class 'int'>
# 7
# <class 'float'>
# 2.5
# <class 'int'>
# <class 'float'>

# %%
print(2 + 3 * 4)
print((2+3)*4)
age = 15
print("Age: " + str(age))
print(10/6)
print(round(10/6,3))
print(20 % 5)
print(21 % 5)
print(22 % 5)
print(3**2)
print(5**2)
print(2**10)
number = 5
print("The number is: " + number)
# Out:
# 14
# 20
# Age: 15
# 1.6666666666666667
# 1.667
# 0
# 1
# 2
# 9
# 25
# 1024
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2950/1485048934.py in <cell line: 0>()
#      12 print(2**10)
#      13 number = 5
# ---> 14 print("The number is: " + number)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(5 +"3")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2950/1347909270.py in <cell line: 0>()
# ----> 1 print(5 +"3")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
points = 10
print(points)

points = points * 2
print(points)

points = points - 5
print(points)

word = "abc"

print(word * 2)
print(word + word)
# Out:
# 10
# 20
# 15
# abcabc
# abcabc

# %%
num1 = 2
num2 = 4

print(num1 + num2)  # חיבור
print(num1 - num2)  # חיסור
print(num1 * num2)  # כפל
print(num1 / num2)  # חילוק
print(num1 ** num2) # חזקה
print(num1 % num2)  # שארית
print(num1 // num2) # חילוק שלם
# Out:
# 6
# -2
# 8
# 0.5
# 16
# 2
# 0

# %%
word = "abc"

print(word * 2)
print(word + word)
# Out:
# abcabc
# abcabc

# %%
num1 = 4
num2 = 6.7
num3 = "67"

print(num1 + num2 + num3)
print(num1 * num3 *num2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2950/2385787635.py in <cell line: 0>()
#       3 num3 = "67"
#       4
# ----> 5 print(num1 + num2 + num3)
#       6 print(num1 * num3 *num2)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
exam_result_sarah = 76
exam_result_ben = 80
exam_result_guy = 100
exam_result_tom = 96
print(exam_result_sarah + exam_result_guy + exam_result_tom + exam_result_ben)
print((exam_result_sarah + exam_result_ben + exam_result_guy + exam_result_tom)/4)
print(round((exam_result_sarah + exam_result_ben + exam_result_guy + exam_result_tom)/4))
print(type(round((exam_result_sarah + exam_result_ben + exam_result_guy + exam_result_tom)/4)))
# Out:
# 352
# 88.0
# 88
# <class 'int'>

# %%
price = 10.67
quantity = 25
print(price * quantity)
print(type(price * quantity))
# Out:
# 266.75
# <class 'float'>

# %%
print("5" + "5")
print(5 + 5)
print("5" + 5)
print("ha" * 3)
print(3.5 * "ha")
# Out:
# 55
# 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2950/2909835067.py in <cell line: 0>()
#       1 print("5" + "5")
#       2 print(5 + 5)
# ----> 3 print("5" + 5)
#       4 print("ha" * 3)
#       5 print(3.5 * "ha")
#
# TypeError: can only concatenate str (not "int") to str

# %%
seconds = 367
minutes = seconds / 60
print(minutes)
print(type(minutes))
print(round(minutes))
print(type(round(minutes)))
# Out:
# 6.116666666666666
# <class 'float'>
# 6
# <class 'int'>

# %%
word = "abc"

print(word * 2)
print(word + word)
# Out:
# abcabc
# abcabc

# %%
number = "5"
print("The number is: " + number)
# Out:
# The number is: 5
