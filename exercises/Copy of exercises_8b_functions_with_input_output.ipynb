# %% [markdown]
# 1. Write a function that takes in a name as a parameter and then prints it.
#
# Call the function passing in a name argument.
#
# Example:
#
# function: greet_person(name)
#
# that prints: 'Hi [name], welcome!'.

# %%
def greet_person():
    enter_name = input("enter name: ")
    print("hello!" , enter_name , ", Welcome!")

greet_person()
# Out:
# enter name: elazar
# hello! elazar ,Welcome

# %% [markdown]
# 2. Write a function that has a parameter age.
#
# Then the function prints the age doubled
#
# Create a variable called **my_age** and assign a value.
#
# Call the function passing **my_age** and save the return value into a variable **my_age_doubled**.
#
# Now write a boolean expression that checks if the return value from the function eequals my_age * 2. Print the result.

# %%
def age():
    enter_age = int(input("enter age: "))
    my_age = enter_age
    my_age_doubled = my_age * 2
    print(my_age_doubled)

age()
# Out:
# enter age: 2
# 4

# %% [markdown]
# 3. Write a function that takes in 2 parameters:
#
# 1) an ice cream flavor
#
# 2) "cone" or "cup"
#
# Then the function prints both values, using an fstring.
#
# Call the function 2 times with different argument values
#
# Call the function again but pass in the arguments the values in the wrong order,
# not matchng the order of the paramters in the function definition.
#
# See the response printed is not what is expected.
#
# Now the function again with keyword arguments and change the order that the arguments are passed in and see that it still works correctly.

# %%
import random
def ice_cream():
    ice_cream_flavor_list = ["chocolate", "vanilla", "strawberry", "pistachio", "banana", "cookie"]
    for flavor in ice_cream_flavor_list:
        flavor = random.choice(ice_cream_flavor_list)
    with_cone = "cone"
    print("i'll have a" , with_cone , "with" , flavor , "flavor please!")


ice_cream()
ice_cream()


def reverse_ice_cream():
    reverse_ice_cream_flavor_list = ["chocolate", "vanilla", "strawberry", "pistachio", "banana", "cookie"]
    for flavor in reverse_ice_cream_flavor_list:
        flavor = (reversed(random.choice(reverse_ice_cream_flavor_list)))
    with_cone = "cone"
    print("i'll have a" , with_cone , "with" , flavor , "flavor please!")

reverse_ice_cream()
reverse_ice_cream()
reverse_ice_cream()
reverse_ice_cream()
# Out:
# i'll have a cone with strawberry flavor please!
# i'll have a cone with pistachio flavor please!
# i'll have a cone with <reversed object at 0x7fa6beebd5d0> flavor please!
# i'll have a cone with <reversed object at 0x7fa6beebe230> flavor please!
# i'll have a cone with <reversed object at 0x7fa6beebd5d0> flavor please!
# i'll have a cone with <reversed object at 0x7fa6beebe230> flavor please!

# %%
def fun_dessert(ice_cream_flavor,cone):
    print("i'll have a" , ice_cream_flavor , "with" , cone , "please")

fun_dessert("chocolate","cone")
fun_dessert("vanilla" , "a cup")
# Out:
# i'll have a chocolate with cone please
# i'll have a vanilla with a cup please

# %% [markdown]
# 4)
# Write a function with three parameters:
#
# friend_name, movie_title, snack.
#
# Then prints an invitation sentence using all three, such as Welcome **Moshe** to the **Spiderman** movie, enjoy your **popcorn**!
#
# Call the function 2 times with different argument values
#
# Call the function a 3rd time with 2 argument values and not 3, what happens?

# %%
def invitation():
    friend_name = "yaron"
    movie_title = "saw 1"
    snack = "popcorn"
    print("welcome" , friend_name , "to", movie_title , ", enjoy your", snack , "!" )

invitation()
invitation()
# Out:
# welcome yaron to saw 1 , enjoy your popcorn !
# welcome yaron to saw 1 , enjoy your popcorn !

# %%
def invitation(friend_name , movie_title , snack):
    print("welcome" , friend_name , "to", movie_title , "enjoy your" , snack)

invitation("yaron" , "saw2" , "chips")
invitation("david" , "hellraiser" , "hotdog")
# Out:
# welcome yaron to saw2 enjoy your chips
# welcome david to hellraiser enjoy your hotdog

# %% [markdown]
# 5)
# Write a function that takes in a favorite food as a parameter.
#
# Then it prints the food value and also the number of letters in the food (using the len() function)

# %%
def food(favorite_food):
    print("favorite food: " , favorite_food)
    print(len(favorite_food))
food("pizza")
# Out:
# favorite food:  pizza
# 5

# %% [markdown]
# 6. Write a function that asks the user to enter a name.
#
# Inside the function create a random letter with random.choice().
#
# Can import the library **string** and use method: **string.ascii_letters**
#
# The function prints both the name entered and the random letter with a f string, such as:
#
# f"Name entered: {name} Letter: {random_letter}"
#
# The function code then checks if the random letter appears in the name entered, and returns True if yes and False if not.

# %%
import string
import random

def name():
    name = input("enter name: ")
    print("the name is" , name)

name()
# Out:
# enter name: aaa
# the name is aaa

# %%
def find_letter_in_name(name):
    letter = random.choice(string.ascii_lowercase)
    print("the name is:" , name)
    print("the letter is: " , letter)
    if letter in name:
        return True
    else:
        return False

find_letter_in_name("elazar")
# Out:
# the name is: elazar
# the letter is:  r
# True

# %% [markdown]
# **7. Print a List With Item Numbers**
#
# Write a function that receives a list.
#
# And then prints the list numbered, such as:
#
# 1. blue
# 2. green
# 3. yellow

# %%
def color_list():
    colors = ["1. blue", "2. green", "3. yellow"]
    for color in colors:
        print(color)

color_list()
# Out:
# 1. blue
# 2. green
# 3. yellow

# %%
def color_list(color):
    print(color)



color_list("1. yellow")
color_list("2. blue")
color_list("3. green")
# Out:
# 1. yellow
# 2. blue
# 3. green

# %%
def color_list(number,color):
    print(number,color)

color_list(1,"yellow")
color_list(2,"green")
color_list(3,"red")
# Out:
# 1 yellow
# 2 green
# 3 red

# %% [markdown]
# **8. Write a function that takes in a list of colors and prints each item.**
#
# **But before it prints each item it checks if the type of the value passed in is a list and then checks if the list is empty or not.**
#
# 1. Create a list;
#
# Example: colors = ["blue", "green", "yellow"]
#
# 2. Create a function **print_list(my_list)**
#
# 3. Inside the function, it first checks if the argument passed is of type list (can use type() function)
#
# a) If it is not a list then print an error message f"The value passed in is not a list {my_list}", and exit the function with return.
#
# b) If is a list then continue to the next lines in the function.
#
# 4. The function then checks if the list is empty or not.
#
# a) If the list is empty then print an error message f"The lsit is empty {my_list}", and exit the function with return.
#
# b) If the list is not empty then continue with the function and use a for loop to print each item in the list

# %%
color_list = ["blue", "green", "yellow"]
print(type(color_list))

if type(color_list) == list:
    print("is a list")
else:
    print("not a list")


color_list_tuple = ("orange", "gold", "cyan")
print(type(color_list_tuple))

if type(color_list_tuple) == list:
    print("is a list")
else:
    print("not a list")
# Out:
# <class 'list'>
# is a list
# <class 'tuple'>
# not a list

# %%
def list_colors ():
    color1 = input("enter first color: ")
    color2 = input("enter second color: ")
    color3 = input("enter third color: ")
    list = [color1, color2, color3]
    print(list)
    print(type(list))



list_colors()
# Out:
# enter first color: yellow
# enter second color: blue
# enter third color: orange
# ['yellow', 'blue', 'orange']
# <class 'list'>

# %%
def color_list():
    color1 = input("enter first color: ")
    color2 = input("enter second color: ")
    color3 = input("enter final color: ")

    colors_in_tuple = (color1 , color2 , color3)
    colors_in_list = [color1 , color2 , color3]

    print(type(colors_in_tuple))
    print(type(colors_in_list))

color_list()
# Out:
# enter first color: red
# enter second color: green
# enter final color: blue
# <class 'tuple'>
# <class 'list'>

# %%
def color_list(color_list):
    print("color list: " , color_list)
    print(type(color_list))




color_list("red, green, blue")
# Out:
# color list:  red, green, blue
# <class 'str'>

# %%
color_list = ["yellow", "cyan", "magneta"]
print(type(color_list))
if type(color_list) == list:
    print("its a list")
else:
    print("not a list")
# Out:
# <class 'list'>
# its a list

# %%
def list_color():
 color_list = ("yellow", "cyan", "magneta")
 print(type(color_list))
 if type(color_list) == list:
    print("its a list")
 else:
    print("not a list")


list_color()
# Out:
# <class 'tuple'>
# not a list

# %%
def list_color(color_list1,color_list2):
    print(type(color_list1))
    if type(color_list1) == list:
        print("is a list")
    else:
        print("not a list")

    print(type(color_list2))
    if type(color_list2) == list:
        print("is a list")
    else:
        print("not a list")

#list_color([#color_list1] , #(color_list2))

# %% [markdown]
# **9) Write a function that receives a number and returns whether it is even.**
#
# Reminder to use the modulo % operator
#
# Call the function 2 times, once with an odd number and once with an even number

# %%
def confirm_number():
    even_number = int(input("enter number: "))
    confirm_equation = even_number #and the equation to confirm it even
    if confirm_equation #is even number:
        return #confirm_equation
    if confirm_equation #is not an even number:
        then #DO NOT RETURN THE EVEN NUMBER use else?

    even_number()
    even_number()

# %%
def confirm_number(even,odd):
    #print(calculation of even , calculation of odd)


    #confirm_number(#even-add equation,odd-add equation)

    #call confirm_number(even,odd)
    #call confirm_number(even,odd)

# %%
def number (num1):
    if num1 %2==0:
        print("even")
    else:
        print("odd")

number(5)
number(6)
# Out:
# odd
# even

# %%
def number (num1,num2):
    if num1 % 2 == 0:
        print("even")
    if num2 % 2 != 0:
        print("odd")
number (4,3)
# Out:
# even
# odd

# %% [markdown]
# **10) Write a function that takes in a word as a parameter and returns the number of vowels it contains.**
#
# Can use a for loop to loop through the letters in the word,
# and then check if each letter is in a list of values: ["a", "e", "i", "o", "u"].
#
# The function should return the number of vowels found in the word.
#
# Call the function with different words.

# %%
prisoner_list = ["khajiit", "imperial", "elf", "redguard", "orc", "nord"]

check_race_prisoner = input("enter prisoner race: ")

if check_race_prisoner in prisoner_list:
    print("he goes to the block")

if check_race_prisoner not in prisoner_list:
    print("hes not in the list, what to do?")
# Out:
# enter prisoner race: altmer
# hes not in the list, what to do?

# %%
def imperial_prison ():
    prisoner_list = ["khajiit", "imperial", "bosmer", "orsimer", "nord", "argonian"]
    for prisoner in prisoner_list:

        prisoner = input("enter prisoner race: ")
        if prisoner in prisoner_list:
            print ("hes in the list he goes to the block")
        if prisoner not in prisoner_list:
            print("hes not on the list what to do with him?")
            break



imperial_prison()
# Out:
# enter prisoner race: khajiit
# hes in the list he goes to the block
# enter prisoner race: fairy
# hes not on the list what to do with him?

# %%
word = input("enter a word: ")
vowel_list = ["e", "l", "a", "z", "a", "r"]
for word in vowel_list:
    print(word)

print(len(vowel_list))
# Out:
# enter a word: elazar
# e
# l
# a
# z
# a
# r
# 6

# %%
word = input("Enter a word: ")

vowels = ["a", "e", "i", "o", "u"]
count = 0

for letter in word:
    if letter in vowels:
        count += 1

print("Number of vowels:", count)
# Out:
# Enter a word: cat
# Number of vowels: 1

# %%
word = input("enter a word: ")
vowel_list = ["e", "l", "a", "z", "a", "r"]
for word in vowel_list:
    print(word)

print(len(vowel_list))
# Out:
# enter a word: elazar
# e
# l
# a
# z
# a
# r
# 6

# %%
letter = input("enter letter: ")
print("letter" , letter)
if letter not in "Elazar":
    print("not in name")
else:
    print("is in name")
# Out:
# enter letter: y
# letter y
# not in name

# %% [markdown]
# **11. Print a Word Backwards**
#
# Write a function that receives a word.
#
# Use a loop to print each letter in reverse order.
#
# Return the result as 1 string

# %%
word = input("enter a word: ")
print(word)
for letters in word:
    print(letters)
# Out:
# enter a word: cats
# cats
# c
# a
# t
# s

# %%
word = input("enter a word: ")
for letters in reversed (word):
    print(letters)
# Out:
# enter a word: cats
# s
# t
# a
# c

# %% [markdown]
# **12. Count a Specific Letter**
#
# Write a function that receives 2 parameters:
#
# a word
# a letter
#
# The function then returns how many times the letter appears in the word.
#
# Example:
#
# count_letter("banana", "a")
#
# returns:  3 **bold text**

# %%
def letter(word,letter):

# %%
word = input("Enter a word: ")

vowels = ["a", "e", "i", "o", "u"]
count = 0

for letter in word:
    if letter in vowels:
        count += 1

print("Number of vowels:", count)
# Out:
# Enter a word: cat
# Number of vowels: 1

# %%
word = input("enter a word: ")
vowel_list = ["e", "l", "a", "z", "a", "r"]
for word in vowel_list:
    print(word)

print(len(vowel_list))
# Out:
# enter a word: elazar
# e
# l
# a
# z
# a
# r
# 6

# %%
colors = ["blue", "green", "yellow", "purple", "orange", "red"]
for color in colors:
    print(color)
    if len(color)>5:
        print("longer than 5")
    if len(color)<5:
        print("shorter than 5")
# Out:
# blue
# shorter than 5
# green
# yellow
# longer than 5
# purple
# longer than 5
# orange
# longer than 5
# red
# shorter than 5

# %%
letter = input("enter letter: ")
print("letter" , letter)
if letter not in "Elazar":
    print("not in name")
else:
    print("is in name")
# Out:
# enter letter: y
# letter y
# not in name
